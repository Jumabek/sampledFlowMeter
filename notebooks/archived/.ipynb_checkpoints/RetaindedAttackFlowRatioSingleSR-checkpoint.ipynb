# %%
import glob
import os
from os.path import join
from numpy import genfromtxt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
# %matplotlib inline

# %%
def get_pkt_count(dirs,ending):
    counts = []
    for d in dirs:
        num_sampled_pkts = 0
        for f in glob.glob(join(d,ending)):
            num_sampled_pkts += int(open(f).readline())
        counts.append(num_sampled_pkts)
    return counts

# %%
def get_immediate_subdirs(a_dir, only=''):
    if only=='':
        return [os.path.join(a_dir, name) for name in os.listdir(a_dir) 
                if os.path.isdir(os.path.join(a_dir, name)) and name.endswith('_l')]
    else:
        return [os.path.join(a_dir, name) for name in os.listdir(a_dir)
                if os.path.isdir(os.path.join(a_dir, name)) and name.endswith('_l') and (only in name or 'whole' in name)]

# %%
def get_flow_dists(dirs):
    results = []
    for d in dirs:
        df = pd.read_csv(join(d,'label_dist.csv'),header=None,names=['Label','Count'])
        results.append(df)
            
    return results

# %%
def get_count4whole(d,ending):
    num_sampled_pkts = 0
    for f in glob.glob(join(d,ending)):
        num_sampled_pkts += int(open(f).readline())
    return num_sampled_pkts

# %%
def get_flow_dist4whole(d):    
    df = pd.read_csv(join(d,'label_dist.csv'),header=None,names=['Label','Count'])          
    return df

# %%
def get_count_dir_names(dirs,ending):
    pkt_counts = np.array(get_pkt_count(dirs,ending))
    flow_dists = get_flow_dists(dirs)
    dir_names = np.array([os.path.basename(dir)[:-2] for dir in dirs])
        
    sorted_index = np.argsort(dir_names)
    pkt_counts = pkt_counts[sorted_index]
    flow_dists = [flow_dists[i] for i in sorted_index]
    dir_names = dir_names[sorted_index]
    
    return flow_dists,pkt_counts,dir_names

# %%
import math
def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.

    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """

    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0, 'right': 1, 'left': -1}
    max_height = 0
    for rect in rects:
        height = rect.get_height()
        if height > max_height:
            max_height = height
            
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{0:.2f}%'.format(100*height/max_height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(offset[xpos]*3, 1),  # use 3 points offset
                    textcoords="offset points",  # in both directions
                    ha=ha[xpos], va='bottom')

# %%
def plot_comparison(dir_names,counts,ax,dataset_name,y_label):
    ind = np.arange(len(dir_names))*20
    width=15
    N = len(dirs)
    colors = []
    labels = []
    for dir_name in dir_names:
        if 'sk_sr' in dir_name:
            color='orange'
            label = 'sketchflow'
        elif 'sgs_e' in dir_name:
            color = 'green'
            label = 'sgs'
        elif 'sf_sr' in dir_name:
            color = 'blue'
            label = 'sFlow'
        elif 'ffs_(' in dir_name:
            color = 'red'
            label = 'Fast Filtered Sampling'
        elif 'sel' in dir_name:
            color = 'purple'
            label = 'selective flow samp.'
        elif 'whole' in dir_name or 'cicflow' in dir_name:
            color = 'gray'
            label = 'whole data'
        else:
            print('Investigate plot_comparison',dir_name)
            
        colors.append(color)
        labels.append(label)
        
    rects = ax.bar(ind,counts,label=dataset_name,width=width,color=colors)

    #Add some text for labels, title and custom x-axis tick labels, etc.    
    #ax.set_title('Finding Equivalent Sampling Rate for comparision')
    ax.set_xticks(ind)
    ax.set_xticklabels(dir_names,rotation=45)
    ax.set_ylabel(y_label)
    ax.legend()
    ax.grid()
    #ax.margins(0.15)
    autolabel(rects)

# %%
def extract_sampler_names(dir_names):
    colors = []
    sampler_names = []
    for dir_name in dir_names:
        if 'sk_sr' in dir_name:
            color='orange'
            label = 'SketchFlow Sampling'
        elif 'sgs_e' in dir_name:
            color = 'green'
            label = 'Sketch Guided Sampling'
        elif 'sf_sr' in dir_name:
            color = 'blue'
            label = 'Random Packet Sampling'
        elif 'ffs_(' in dir_name:
            color = 'red'
            label = 'Fast Filtered Sampling'
        elif 'sel' in dir_name:
            color = 'purple'
            label = 'Selective Flow Sampling'
        elif 'whole' in dir_name or 'cicflow' in dir_name:
            color = 'gray'
            label = 'Without Sampling'
        else:
            print('Investigate plot_comparison',dir_name)
            
        colors.append(color)
        sampler_names.append(label)
    return sampler_names

# %%
root = '/home/juma/data/net_intrusion/CIC-IDS-2018/CSVs_mem_100.0/SR_1'
label = 'CIC-IDS-2018'
ending = '*.spc'

dirs = get_immediate_subdirs(root)

flow_dists,pkt_counts,dir_names = get_count_dir_names(dirs,ending)

whole_index = np.where(dir_names=='whole')[0][0];
whole_df = flow_dists[whole_index]
total_pkts = pkt_counts[whole_index]

sampler_names = extract_sampler_names(dir_names)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-7ecea779b81b> in <module>
#       7 flow_dists,pkt_counts,dir_names = get_count_dir_names(dirs,ending)
#       8
# ----> 9 whole_index = np.where(dir_names=='whole')[0][0]
#      10 whole_df = flow_dists[whole_index]
#      11 total_pkts = pkt_counts[whole_index]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
    attack_labels = whole_df['Label'].values
    header = np.concatenate((['Sampling technique'],attack_labels))
    df = pd.DataFrame(columns=header)
    flow_counts = defaultdict(list)
    flow_counts['Sampling technique'].append('No sampling')
    
    for i,row in whole_df.iterrows():
        flow_counts[row[0]].append('100') # for each label     
    
    for i,sampler_name in enumerate(sampler_names):
        if "Without" in sampler_name:
            continue
        # below here would form a single table for Sampling_method x Attacks for specific SR
        #sampler_name = sampler_names[i]
        flow_counts['Sampling technique'].append(sampler_name)
        flow_dist_df = flow_dists[i]
        print('******************{0:20}*********************'.format(sampler_name))
            
        for label in attack_labels:
                #make list dictionary for each attack type on sampler names
                if len(flow_dist_df[flow_dist_df['Label']==label]['Count'])>0:
                    num_flows = flow_dist_df[flow_dist_df['Label']==label]['Count'].values[0]
                else:
                    num_flows = 0
                original_num_flows = whole_df[whole_df['Label']==label]['Count'].values[0]
                
                flow_counts[label].append('{:.2f}'.format(100*num_flows/original_num_flows))
                print('{:30}'.format(label),num_flows)
            
    pd.DataFrame.from_dict(flow_counts).to_csv(join(root,'retained_ratio.csv'),index=False)
# Out:
# ******************Fast Filtered Sampling*********************
# Benign                         14789
# Brute Force-Web                146
# Brute Force-XSS                114
# DDoS attacks-LOIC-HTTP         26575
# DDoS-HOIC                      110713
# DDoS-LOIC-UDP                  2465
# DoS-GoldenEye                  2753
# DoS-Hulk                       72280
# DoS-SlowHTTPTest               2389
# DoS-Slowloris                  983
# FTP-BruteForce                 4049
# Infiltration                   19
# SQL Injection                  5
# SSH-BruteForce                 36636
# ******************Fast Filtered Sampling*********************
# Benign                         371429
# Brute Force-Web                359
# Brute Force-XSS                108
# DDoS attacks-LOIC-HTTP         229027
# DDoS-HOIC                      359882
# DDoS-LOIC-UDP                  480
# DoS-GoldenEye                  23975
# DoS-Hulk                       26388
# DoS-SlowHTTPTest               70834
# DoS-Slowloris                  2575
# FTP-BruteForce                 84964
# Infiltration                   15
# SQL Injection                  71
# SSH-BruteForce                 14354
# ******************Selective Flow Sampling*********************
# Benign                         10949
# Brute Force-Web                145
# Brute Force-XSS                109
# DDoS attacks-LOIC-HTTP         25147
# DDoS-HOIC                      104261
# DDoS-LOIC-UDP                  2477
# DoS-GoldenEye                  2543
# DoS-Hulk                       70698
# DoS-SlowHTTPTest               2157
# DoS-Slowloris                  954
# FTP-BruteForce                 3849
# Infiltration                   22
# SQL Injection                  2
# SSH-BruteForce                 35331
# ******************Selective Flow Sampling*********************
# Benign                         303630
# Brute Force-Web                294
# Brute Force-XSS                116
# DDoS attacks-LOIC-HTTP         290557
# DDoS-HOIC                      675538
# DDoS-LOIC-UDP                  1490
# DoS-GoldenEye                  27431
# DoS-Hulk                       81810
# DoS-SlowHTTPTest               63981
# DoS-Slowloris                  6521
# FTP-BruteForce                 90911
# Infiltration                   43
# SQL Injection                  46
# SSH-BruteForce                 63594
# ******************Random Packet Sampling*********************
# Benign                         3718
# Brute Force-Web                129
# Brute Force-XSS                110
# DDoS attacks-LOIC-HTTP         2692
# DDoS-HOIC                      76571
# DDoS-LOIC-UDP                  2476
# DoS-GoldenEye                  120
# DoS-Hulk                       74966
# DoS-SlowHTTPTest               11
# DoS-Slowloris                  279
# FTP-BruteForce                 415
# Infiltration                   29
# SQL Injection                  0
# SSH-BruteForce                 41120
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-4a888c7fcbe9> in <module>
#      14     #sampler_name = sampler_names[i]
#      15     flow_counts['Sampling technique'].append(sampler_name)
# ---> 16     flow_dist_df = flow_dists[i]
#      17     print('******************{0:20}*********************'.format(sampler_name))
#      18
#
# IndexError: list index out of range
